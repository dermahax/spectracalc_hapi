# %% [markdown]
#  ## CH4 Spectra of passive and of active cams

# %% [markdown]
# *Script to illustrate the filter width of a passive gas camera*

# %%
# %%capture
# %load_ext autoreload
# %autoreload 2
import os
from pathlib import Path
import matplotlib
import configparser
os.chdir('..')
from classes import Spectra, Observer, HiddenPrints

# %%
# %%capture
### Selektivität

VMR_Methan = 500-6
VMR_Water = 10E-2

#%% 1. create a spectrum
selectivity_passiv = Spectra(name = 'CH4_selectivity_passiv')

#%% 2. add an observer
selectivity_passiv.observer = Observer(unit  = 'lam',      #'wav' : wavenumer [1/cm] | 'lam' : wavelength [nm].
                                lower = 3080.  , #lower =  3260.,    
                                upper = 3530,  #upper =  3260.6,   
                                )
#%% 3. add gas_cells (may consist of multiple gasses) with gasses

# cell 1
selectivity_passiv.add_gas_cell(temperature    = 296,          # K. Default is 296
                         pressure       = 1,            # atm. Default is 1
                         length         = 100,           # cm. Default is 10
                         no_gasses      = 1)            # number of gasses. Default is 1

selectivity_passiv.gas_cells[-1].add_gas(gas_name  = "H2O",    # as in hitran
                                VMR        = VMR_Water)    # E-6 = ppm 

# cell 0
selectivity_passiv.add_gas_cell(temperature    = 296,          # K. Default is 296
                         pressure       = 1,            # atm. Default is 1
                         length         = 100,           # cm. Default is 10
                         no_gasses      = 1)            # number of gasses. Default is 1

selectivity_passiv.gas_cells[-1].add_gas(gas_name  = "CH4",    # as in hitran
                                VMR        = VMR_Methan)    # E-6 = ppm 




#%% 4. download (running hapi functions)
selectivity_passiv.download(line_list = False,         # by setting to false, the linelist will nor be downloaded nor plotted.
                     step      = 0.5         # The step size determines the resolution of the graph. It is in the unit of wavenumbers (1/cm).
                    )  


### Selektivität aktiv


#%% 1. create a spectrum
selectivity_active = Spectra(name = 'CH4_selectivity_active')

#%% 2. add an observer
selectivity_active.observer = Observer(unit  = 'lam',      #'wav' : wavenumer [1/cm] | 'lam' : wavelength [nm].
                                lower = 3265.  ,    
                                upper = 3275,  
                                )
#%% 3. add gas_cells (may consist of multiple gasses) with gasses

# cell 1
selectivity_active.add_gas_cell(temperature    = 296,          # K. Default is 296
                         pressure       = 1,            # atm. Default is 1
                         length         = 100,           # cm. Default is 10
                         no_gasses      = 1)            # number of gasses. Default is 1

selectivity_active.gas_cells[-1].add_gas(gas_name  = "H2O",    # as in hitran
                                VMR        = VMR_Water)    # E-6 = ppm 

# cell 0
selectivity_active.add_gas_cell(temperature    = 296,          # K. Default is 296
                         pressure       = 1,            # atm. Default is 1
                         length         = 100,           # cm. Default is 10
                         no_gasses      = 1)            # number of gasses. Default is 1

selectivity_active.gas_cells[-1].add_gas(gas_name  = "CH4",    # as in hitran
                                VMR        = VMR_Methan)    # E-6 = ppm 


#%% 4. download (running hapi functions)
selectivity_active.download(line_list = False,         # by setting to false, the linelist will nor be downloaded nor plotted.
                     step      = 0.01         # The step size determines the resolution of the graph. It is in the unit of wavenumbers (1/cm).
                    )  

###############################

### Sensitivität passiv


#%% 1. create a spectrum
sensitivity_passiv = Spectra(name = 'CH4_sensitivity_passiv')

#%% 2. add an observer
sensitivity_passiv.observer = Observer(unit  = 'lam',      #'wav' : wavenumer [1/cm] | 'lam' : wavelength [nm].
                                lower = 3080.  , #lower =  3260.,    
                                upper = 3530,  #upper =  3260.6,   
                                )
#%% 3. add gas_cells (may consist of multiple gasses) with gasses


# cell 0
sensitivity_passiv.add_gas_cell(temperature    = 296,          # K. Default is 296
                         pressure       = 1,            # atm. Default is 1
                         length         = 100,           # cm. Default is 10
                         no_gasses      = 1)            # number of gasses. Default is 1

sensitivity_passiv.gas_cells[-1].add_gas(gas_name  = "CH4",    # as in hitran
                                VMR        = VMR_Methan)    # E-6 = ppm 




#%% 4. download (running hapi functions)
sensitivity_passiv.download(line_list = False,         # by setting to false, the linelist will nor be downloaded nor plotted.
                     step      = 0.5         # The step size determines the resolution of the graph. It is in the unit of wavenumbers (1/cm).
                    )  



### Sensitivität aktiv


#%% 1. create a spectrum
sensitivity_active = Spectra(name = 'CH4_sensitivity_active')

#%% 2. add an observer
sensitivity_active.observer = Observer(unit  = 'lam',      #'wav' : wavenumer [1/cm] | 'lam' : wavelength [nm].
                                lower = 3265.  ,    
                                upper = 3275,  
                                )
#%% 3. add gas_cells (may consist of multiple gasses) with gasses


# cell 0
sensitivity_active.add_gas_cell(temperature    = 296,          # K. Default is 296
                         pressure       = 1,            # atm. Default is 1
                         length         = 100,           # cm. Default is 10
                         no_gasses      = 1)            # number of gasses. Default is 1

sensitivity_active.gas_cells[-1].add_gas(gas_name  = "CH4",    # as in hitran
                                VMR        = VMR_Methan)    # E-6 = ppm 


#%% 4. download (running hapi functions)
sensitivity_active.download(line_list = False,         # by setting to false, the linelist will nor be downloaded nor plotted.
                     step      = 0.01         # The step size determines the resolution of the graph. It is in the unit of wavenumbers (1/cm).
                    )
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[2], line 38
#      31 selectivity_passiv.gas_cells[-1].add_gas(gas_name  = "CH4",    # as in hitran
#      32                                 VMR        = VMR_Methan)    # E-6 = ppm
#      37 #%% 4. download (running hapi functions)
# ---> 38 selectivity_passiv.download(line_list = False,         # by setting to false, the linelist will nor be downloaded nor plotted.
#      39                      step      = 0.5         # The step size determines the resolution of the graph. It is in the unit of wavenumbers (1/cm).
#      40                     )
#      43 ### Selektivität aktiv
#      44
#      45
#      46 #%% 1. create a spectrum
#      47 selectivity_active = Spectra(name = 'CH4_selectivity_active')
#
# File ~\OneDrive - Endress+Hauser\Python\hapi_1c\spectracalc_hapi\classes.py:271, in Spectra.download(self, line_list, min_intensity, step, HITRAN_units)
#     267 try:
#     268     print('to check: ----------------------- \n',
#     269           [(gas.M, gas.I, gas.VMR) for gas in gas_cell.gasses])
# --> 271     gas_cell.nu, gas_cell.coef = absorptionCoefficient_Voigt(
#     272         Components=[(gas.M, gas.I, gas.VMR) for gas in gas_cell.gasses],
#     273         SourceTables=[gas.gas_name for gas in gas_cell.gasses],
#     274         HITRAN_units=False,
#     275         Environment={'T': gas_cell.temperature, 'p': gas_cell.pressure},
#     276         Diluent= gas_cell.diluent,
#     277         OmegaStep= step,
#     278         OmegaRange = [self.observer.lower_wav, self.observer.upper_wav])
#     279     # if HITRAN_units:  # to do. see https://github.com/hapijs/hapi/issues/4206
#     280
#     281     # wavelength conversion
#     282     gas_cell.lam = np.flip(np.asarray([Helpers.wav2lam(wav) for wav in gas_cell.nu]))
#
# File ~\OneDrive - Endress+Hauser\Python\hapi_1c\spectracalc_hapi\hapi.py:35565, in absorptionCoefficient_Voigt(*args, **kwargs)
#   35564 def absorptionCoefficient_Voigt(*args,**kwargs):
# > 35565     return absorptionCoefficient_Generic(*args,**kwargs,
#   35566                                           profile=PROFILE_VOIGT,
#   35567                                           calcpars=calculateProfileParametersVoigt)
#
# File ~\OneDrive - Endress+Hauser\Python\hapi_1c\spectracalc_hapi\hapi.py:35473, in absorptionCoefficient_Generic(Components, SourceTables, partitionFunction, Environment, OmegaRange, OmegaStep, OmegaWing, IntensityThreshold, OmegaWingHW, GammaL, HITRAN_units, LineShift, File, Format, OmegaGrid, WavenumberRange, WavenumberStep, WavenumberWing, WavenumberWingHW, WavenumberGrid, Diluent, LineMixingRosen, profile, calcpars, exclude, DEBUG)
#   35471     val = Diluent[key]
#   35472     if val < 0 or val > 1: # if val < 0 and val > 1:# CHANGED RJH 23MAR18
# > 35473         raise Exception('Diluent fraction must be in [0,1]')
#   35475 # ================= HERE THE GENERIC PART STARTS =====================
#   35477 t = time()
#
# Exception: Diluent fraction must be in [0,1]

# %% [markdown]
# To double check that everything is as desired, you can print a summary of your setup.

# %% [markdown]
# The plot function may be adjusted to ones needs.
# If line list has not been downloaded (step 4), it will not be plotted.

# %%
#%% 5. plot prop const
#matplotlib.rc_file(Path('C:/Users/i13500029/OneDrive - Endress+Hauser/Python/Figures_git/uni_layout_rc'))
config = configparser.ConfigParser()
config.read('C:/Users/i13500029/OneDrive - Endress+Hauser/Python/Figures_git/uni_layout_rc')
matplotlib.rcParams.update(config['halfsize'])

a = selectivity_passiv.plot(#figsize = (246/72, 246 *10/8 / 72),
                figsize = (5.708662653936627, 4.281496990),
                 export = False,
                 fontsize = 10,
                 absorbance = False,
                 prop_const = True,
                )

b = selectivity_active.plot(#figsize = (246/72, 246 *10/8 / 72),
                figsize = (5.708662653936627, 4.281496990),
                 export = False,
                 fontsize = 10,
                 absorbance = False,
                 prop_const = True,
                )

####

c = sensitivity_passiv.plot(#figsize = (246/72, 246 *10/8 / 72),
                figsize = (5.708662653936627, 4.281496990),
                 export = False,
                 fontsize = 10,
                 absorbance = False,
                 prop_const = True,
                )

d = sensitivity_active.plot(#figsize = (246/72, 246 *10/8 / 72),
                figsize = (5.708662653936627, 4.281496990),
                 export = False,
                 fontsize = 10,
                 absorbance = False,
                 prop_const = True,
                )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 15
#       5 matplotlib.rcParams.update(config['halfsize'])
#       7 a = selectivity_passiv.plot(#figsize = (246/72, 246 *10/8 / 72),
#       8                 figsize = (5.708662653936627, 4.281496990),
#       9                  export = False,
#    (...)
#      12                  prop_const = True,
#      13                 )
# ---> 15 b = selectivity_active.plot(#figsize = (246/72, 246 *10/8 / 72),
#      16                 figsize = (5.708662653936627, 4.281496990),
#      17                  export = False,
#      18                  fontsize = 10,
#      19                  absorbance = False,
#      20                  prop_const = True,
#      21                 )
#      23 ####
#      25 c = sensitivity_passiv.plot(#figsize = (246/72, 246 *10/8 / 72),
#      26                 figsize = (5.708662653936627, 4.281496990),
#      27                  export = False,
#    (...)
#      30                  prop_const = True,
#      31                 )
#
# NameError: name 'selectivity_active' is not defined
